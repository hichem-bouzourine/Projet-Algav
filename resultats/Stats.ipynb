# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# # Tas Min

# %% [markdown]
# ## Ajouts Itératifs

# %%
# Lecture des données depuis le fichier CSV 
# Toute les clés ont été utilisées
df_ajout_iteratif_arbre = pd.read_csv('./ajout_iteratifs_tas_arbre.csv')
df_ajout_iteratif_tab = pd.read_csv('./ajout_iteratifs_tas_tab.csv')

# %%
df_ajout_iteratif_arbre['moyenne']
#df_ajout_iteratif_tab['Taille']
# Out:
# 0    9.74228
# 1    3.76576
# 2    1.80194
# 3    2.12828
# 4    1.63580
# 5    1.45248
# 6    7.66946
# 7    2.46694
# Name: moyenne, dtype: float64

# %%
# Extraire les colonnes nécessaires
taille_ajout_iteratif_arbre = df_ajout_iteratif_arbre['Taille']
moyenne_ajout_iteratif_arbre = df_ajout_iteratif_arbre['moyenne']
taille_ajout_iteratif_tab = df_ajout_iteratif_tab['Taille']
moyenne_ajout_iteratif_tab = df_ajout_iteratif_tab['moyenne']

# Créer le graphique
# Créer le graphique
plt.figure(figsize=(10, 6))


# Tracer les données pour l'arbre
plt.plot(taille_ajout_iteratif_arbre, moyenne_ajout_iteratif_arbre, label='Arbre', color='red')


# Tracer les données pour le tableau
plt.plot(taille_ajout_iteratif_tab, moyenne_ajout_iteratif_tab, label='Tableau', color='yellow')

# Ajouter des labels et un titre
plt.title('Temps d\'ajout itératifs en fonction de la taille de la structure')
plt.xlabel('Taille de la structure')
plt.ylabel('Temps moyen d\'ajout (ms)')

# Ajouter une légende
plt.legend()

# Afficher le graphique
#plt.grid(True)
plt.show()

# %% [markdown]
# ## Construction

# %%
# Lecture des données depuis le fichier CSV
df_construction_arbre = pd.read_csv('./construction_tas_arbre.csv')
df_construction_tab = pd.read_csv('./construction_tas_tab.csv')

# %%
# Extraire les colonnes nécessaires
taille_construction_arbre = df_construction_arbre['Taille']
moyenne_construction_arbre = df_construction_arbre['moyenne']
taille_construction_tab = df_construction_tab['Taille']
moyenne_construction_tab = df_construction_tab['moyenne']

# Créer le graphique
# Créer le graphique
plt.figure(figsize=(10, 6))


# Tracer les données pour l'arbre
plt.plot(taille_construction_arbre, moyenne_construction_arbre, label='Arbre', color='red')

# Tracer les données pour le tableau
plt.plot(taille_construction_tab, moyenne_construction_tab, label='Tableau', color='yellow')

# Ajouter des labels et un titre
plt.title('Temps de construction en fonction de la taille de la structure')
plt.xlabel('Taille de la structure')
plt.ylabel('Temps moyen d\'ajout (ms)')

# Ajouter une légende
plt.legend()

# Afficher le graphique
plt.show()

# %% [markdown]
# ## Union

# %%
# Lecture des données depuis le fichier CSV
df_union_arbre = pd.read_csv('./union_tas_arbre.csv')
df_union_tab = pd.read_csv('./union_tas_tab.csv')

# %%
# Extraire les colonnes nécessaires
taille_union_arbre = df_union_arbre['Taille']
moyenne_union_arbre = df_union_arbre['moyenne']
taille_union_tab = df_union_tab['Taille']
moyenne_union_tab = df_union_tab['moyenne']

# Créer le graphique
# Créer le graphique
plt.figure(figsize=(10, 6))


# Tracer les données pour l'arbre
plt.plot(taille_union_arbre, moyenne_union_arbre, label='Arbre', color='red')

# Tracer les données pour le tableau
plt.plot(taille_union_tab, moyenne_union_tab, label='Tableau', color='yellow')

# Ajouter des labels et un titre
plt.title('Temps d\'union de tas en fonction de la taille de la structure')
plt.xlabel('Taille de la structure')
plt.ylabel('Temps moyen d\'ajout (ms)')

# Ajouter une légende
plt.legend()

# Afficher le graphique
plt.show()

# %% [markdown]
# ## Supprimer min

# %%
# Lecture des données depuis le fichier CSV
df_supprMin_arbre = pd.read_csv('./supprMin_tas_arbre.csv')
df_supprMin_tab = pd.read_csv('./supprMin_tas_tab.csv')

# %%
# Extraire les colonnes nécessaires
taille_supprMin_arbre = df_supprMin_arbre['Taille']
moyenne_supprMin_arbre = df_supprMin_arbre['moyenne']
taille_supprMin_tab = df_supprMin_tab['Taille']
moyenne_supprMin_tab = df_supprMin_tab['moyenne']

# Créer le graphique
# Créer le graphique
plt.figure(figsize=(10, 6))


# Tracer les données pour l'arbre
plt.plot(taille_supprMin_arbre, moyenne_supprMin_arbre, label='Arbre', color='red')

# Tracer les données pour le tableau
plt.plot(taille_supprMin_tab, moyenne_supprMin_tab, label='Tableau', color='yellow')

# Ajouter des labels et un titre
plt.title('Temps de suppression du min du tas en fonction de la taille de la structure')
plt.xlabel('Taille de la structure')
plt.ylabel('Temps moyen d\'ajout (ms)')

# Ajouter une légende
plt.legend()

# Afficher le graphique
plt.show()

# %% [markdown]
# # File Binomiale

# %% [markdown]
# ## Ajout

# %%
# Lecture des données depuis le fichier CSV
df_ajout_fileBinomiale = pd.read_csv('./ajout_fileBinomiale.csv')

# %%
# Extraire les colonnes nécessaires
taille_ajout_fileBinomiale = df_ajout_fileBinomiale['Taille']
moyenne_ajout_fileBinomiale = df_ajout_fileBinomiale['moyenne']

# Créer le graphique
# Créer le graphique
plt.figure(figsize=(10, 6))

# Tracer les données pour l'arbre
plt.plot(taille_ajout_fileBinomiale, moyenne_ajout_fileBinomiale,marker="o" ,  label='File Binomiale',color="blue")

# Ajouter des labels et un titre
plt.title('Temps d\'ajout pour l\'ajout d\'un élément dans une file binomiale ')
plt.xlabel('Taille de la structure')
plt.ylabel('Temps moyen d\'construction (ms)')

# Ajouter une légende
plt.legend()

# Afficher le graphique

plt.show()

# %% [markdown]
# ## Construction

# %%
# Lecture des données depuis le fichier CSV
df_construction_fileBinomiale = pd.read_csv('./construction_fileBinomiale.csv')

# %%
# Extraire les colonnes nécessaires
taille_construction_fileBinomiale = df_construction_fileBinomiale['Taille']
moyenne_construction_fileBinomiale = df_construction_fileBinomiale['moyenne']


# Créer le graphique
# Créer le graphique
plt.figure(figsize=(10, 6))

# Tracer les données pour l'arbre
plt.plot(taille_construction_fileBinomiale, moyenne_construction_fileBinomiale, label='File Binomiale',color="blue")


# Ajouter des labels et un titre
plt.title('Temps de construction de file binomiale en fonction de la taille de la structure')
plt.xlabel('Taille de la structure')
plt.ylabel('Temps moyen d\'construction (ms)')

# Ajouter une légende
plt.legend()

# Afficher le graphique

plt.show()

# %% [markdown]
# ## Union

# %%
df_union_fileBinomiale = pd.read_csv('./union_fileBinomiale.csv')

# %%
# Extraire les colonnes nécessaires
taille_union_fileBinomiale = df_union_fileBinomiale['Taille']
moyenne_union_fileBinomiale = df_union_fileBinomiale['moyenne']


# Créer le graphique
# Créer le graphique
plt.figure(figsize=(10, 6))

# Tracer les données pour l'arbre
plt.plot(taille_union_fileBinomiale, moyenne_union_fileBinomiale,marker='o', label='File Binomiale',color="blue")


# Ajouter des labels et un titre
plt.title('Temps de union de file binomiale en fonction de la taille de la structure')
plt.xlabel('Taille de la structure')
plt.ylabel('Temps moyen d\'construction (ms)')

# Ajouter une légende
plt.legend()

# Afficher le graphique
plt.show()

# %% [markdown]
# ## Supprimer min

# %%
df_supprMin_fileBinomiale = pd.read_csv('./supprMin_fileBinomiale.csv')

# %%
# Extraire les colonnes nécessaires
taille_supprMin_fileBinomiale = df_supprMin_fileBinomiale['Taille']
moyenne_supprMin_fileBinomiale = df_supprMin_fileBinomiale['moyenne']


# Créer le graphique
# Créer le graphique
plt.figure(figsize=(10, 6))

# Tracer les données pour l'arbre
plt.plot(taille_supprMin_fileBinomiale, moyenne_supprMin_fileBinomiale,marker='o', label='File Binomiale',color="blue")


# Ajouter des labels et un titre
plt.title('Temps de supprMin de file binomiale en fonction de la taille de la structure')
plt.xlabel('Taille de la structure')
plt.ylabel('Temps moyen d\'construction (ms)')

# Ajouter une légende
plt.legend()

# Afficher le graphique
plt.show()

# %% [markdown]
# # Comparaison - Shakespear

# %% [markdown]
# ## Ajout

# %%
# Lecture des données depuis le fichier CSV
df_ajout_tas_tab_vs_fileBinomiale = pd.read_csv('./ajout_tas_tab_vs_fileBinomiale_shakespeare.csv')

# %%
df_ajout_tas_tab_vs_fileBinomiale['Taille']
# Out:
# 0      100
# 1      200
# 2      500
# 3     1000
# 4     5000
# 5    10000
# 6    20000
# Name: Taille, dtype: int64

# %%
# Extraire les colonnes nécessaires
taille = df_ajout_tas_tab_vs_fileBinomiale['Taille']
moyenne_ajout_tas_tab = df_ajout_tas_tab_vs_fileBinomiale['moyenne_tas']
moyenne_ajout_file = df_ajout_tas_tab_vs_fileBinomiale['moyenne_file']

# Créer le graphique
plt.figure(figsize=(10, 6))
plt.plot(taille, moyenne_ajout_tas_tab, marker='o' , label="Tas (Tableau)", color='red')
plt.plot(taille, moyenne_ajout_file, marker='o', label="File", color='yellow')

# Ajouter des labels et un titre
plt.title('Temps nécessaire pour l\'ajout d\'un élément dans une file binomiale VS Tas min (tab) en fonction de la taille de la file')
plt.xlabel('Taille de la file (nombre de clés)')
plt.ylabel('Temps moyen d\'ajout')


plt.legend()

# Afficher le graphique
plt.show()

# %% [markdown]
# ## SupprMin

# %%
# Lecture des données depuis le fichier CSV
df_supprMin_tas_tab_vs_fileBinomiale = pd.read_csv('./supprMin_tas_tab_vs_fileBinomiale_shakespeare.csv')

# %%
# Extraire les colonnes nécessaires
taille = df_ajout_tas_tab_vs_fileBinomiale['Taille']
moyenne_supprMin_tas_tab = df_supprMin_tas_tab_vs_fileBinomiale['moyenne_tas']
moyenne_supprMin_file = df_supprMin_tas_tab_vs_fileBinomiale['moyenne_file']

# Créer le graphique
plt.figure(figsize=(10, 6))
plt.plot(taille, moyenne_supprMin_tas_tab, marker='o' , label="Tas (Tableau)", color='red')
plt.plot(taille, moyenne_supprMin_file, marker='o', label="File", color='yellow')

# Ajouter des labels et un titre
plt.title('Temps de suppresion du minimum dans une file binomiale VS Tas min (tab) en fonction de la taille de la file')
plt.xlabel('Nombre de clés')
plt.ylabel('Temps moyen de suppression du minimum (ms)')


plt.legend()

# Afficher le graphique
plt.show()

# %% [markdown]
# ## Construction

# %%
# Lecture des données depuis le fichier CSV
df_construction_tas_tab_vs_fileBinomiale = pd.read_csv('./construction_tas_tab_vs_fileBinomiale_shakespeare.csv')

# %%
# Extraire les colonnes nécessaires
taille = df_ajout_tas_tab_vs_fileBinomiale['Taille']
moyenne_construction_tas_tab = df_construction_tas_tab_vs_fileBinomiale['moyenne_tas']
moyenne_construction_file = df_construction_tas_tab_vs_fileBinomiale['moyenne_file']

# Créer le graphique
plt.figure(figsize=(10, 6))
plt.plot(taille, moyenne_construction_tas_tab, marker='o' , label="Tas (Tableau)", color='red')
plt.plot(taille, moyenne_construction_file, marker='o', label="File", color='yellow')

# Ajouter des labels et un titre
plt.title('Temps de construction dans une file binomiale VS Tas min (tab) en fonction de la taille de la file')
plt.xlabel('Nombre de clés')
plt.ylabel('Temps moyen de construction (ms)')


plt.legend()

# Afficher le graphique
plt.show()

# %% [markdown]
# ## Union

# %%
df_union_tas_tab_vs_fileBinomiale = pd.read_csv('./union_tas_tab_vs_fileBinomiale_shakespeare.csv')

# %%
df_union_tas_tab_vs_fileBinomiale["moyenne_file"]
# Out:
# 0    0.03357
# 1    0.00785
# 2    0.00895
# 3    0.01047
# 4    0.01965
# 5    0.01472
# 6    0.03731
# Name: moyenne_file, dtype: float64

# %%
# Extraire les colonnes nécessaires
taille = df_ajout_tas_tab_vs_fileBinomiale['Taille']
moyenne_union_tas_tab = df_union_tas_tab_vs_fileBinomiale['moyenne_tas']
moyenne_union_file = df_union_tas_tab_vs_fileBinomiale['moyenne_file']

# Créer le graphique
plt.figure(figsize=(10, 6))
plt.plot(taille, moyenne_union_tas_tab, marker='o' , label="Tas (Tableau)", color='red')
plt.plot(taille, moyenne_union_file, marker='o', label="File", color='yellow')

# Ajouter des labels et un titre
plt.title('Temps d\'union d\'une file binomiale VS Tas min (tab) en fonction de la taille de la file')
plt.xlabel('Nombre de clé')
plt.ylabel('Temps moyen d\'union (ms)')


plt.legend()

# Afficher le graphique
plt.show()
